# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramendescd/Lab_DataScience/blob/main/Olimpiadas_brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###CARREGANDO O CONJUNTO DE DADOS

# %%
# Importação das bibliotecas a serem utilizadas na análise
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregando o conjunto de dados
df = pd.read_csv('athlete_events.csv')

# %% [markdown]
# ###RENOMEANDO ALGUMAS COLUNAS A SEREM UTILIZADAS PARA ANÁLISE

# %%
# Rename() para renomear colunas do df
df = df.rename(columns={'Age': 'Idade', 'Name': 'Nome', 'Weight': 'Peso', 
                        'Sex':'Sexo', 'Games': 'Jogos', 'Year': 'Ano', 'Sport': 'Esporte',
                        'Medal':'Medalha', 'Season':'Estação', 'Height': 'Altura', 'Time':'Tempo'})

# Verificando se foi renomeada 
print(df)
# Out:
#             ID                      Nome Sexo  Idade  Altura  Peso  \
# 0            1                 A Dijiang    M   24.0   180.0  80.0
# 1            2                  A Lamusi    M   23.0   170.0  60.0
# 2            3       Gunnar Nielsen Aaby    M   24.0     NaN   NaN
# 3            4      Edgar Lindenau Aabye    M   34.0     NaN   NaN
# 4            5  Christine Jacoba Aaftink    F   21.0   185.0  82.0
# ...        ...                       ...  ...    ...     ...   ...
# 271111  135569                Andrzej ya    M   29.0   179.0  89.0
# 271112  135570                  Piotr ya    M   27.0   176.0  59.0
# 271113  135570                  Piotr ya    M   27.0   176.0  59.0
# 271114  135571        Tomasz Ireneusz ya    M   30.0   185.0  96.0
# 271115  135571        Tomasz Ireneusz ya    M   34.0   185.0  96.0
#
#                   Team  NOC        Jogos   Ano Estação            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#               Esporte                                     Event Medalha
# 0          Basketball               Basketball Men's Basketball     NaN
# 1                Judo              Judo Men's Extra-Lightweight     NaN
# 2            Football                   Football Men's Football     NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War    Gold
# 4       Speed Skating          Speed Skating Women's 500 metres     NaN
# ...               ...                                       ...     ...
# 271111           Luge                Luge Mixed (Men)'s Doubles     NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual     NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team     NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four     NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four     NaN
#
# [271116 rows x 15 columns]

# %% [markdown]
# ###FILTRANDO ATLETAS BRASILEIROS

# %%
# Criando um novo df apenas com dados de atletas brasileiros 
atletas_brasileiros_df = df.loc[df['NOC'] == 'BRA']
atletas_brasileiros_df
# Out:
#             ID                        Nome Sexo  Idade  Altura  Peso    Team  \
# 665        386             Alexandre Abeid    M   22.0   194.0  92.0  Brazil
# 666        386             Alexandre Abeid    M   26.0   194.0  92.0  Brazil
# 668        388  Abel Carlos da Silva Braga    M   19.0   190.0  73.0  Brazil
# 781        451         Diana Monteiro Abla    F   21.0   175.0  75.0  Brazil
# 1005       565        Glauclio Serro Abreu    M   26.0   185.0  75.0  Brazil
# ...        ...                         ...  ...    ...     ...   ...     ...
# 268652  134400   Maria Jos "Zz" Bertolotti    F   26.0   190.0   NaN  Brazil
# 269745  134976       Sieglinda Lenk Zigler    F   17.0     NaN   NaN  Brazil
# 269899  135037           Moacir Zimmermann    M   32.0   184.0  70.0  Brazil
# 270478  135289        Zzimo Alves Calazans    M   20.0     NaN   NaN  Brazil
# 270789  135423        Ral Benedito Zumbano    M   22.0     NaN   NaN  Brazil
#
#         NOC        Jogos   Ano Estação            City     Esporte  \
# 665     BRA  1972 Summer  1972  Summer          Munich  Volleyball
# 666     BRA  1976 Summer  1976  Summer        Montreal  Volleyball
# 668     BRA  1972 Summer  1972  Summer          Munich    Football
# 781     BRA  2016 Summer  2016  Summer  Rio de Janeiro  Water Polo
# 1005    BRA  2004 Summer  2004  Summer          Athina      Boxing
# ...     ...          ...   ...     ...             ...         ...
# 268652  BRA  1992 Summer  1992  Summer       Barcelona  Basketball
# 269745  BRA  1936 Summer  1936  Summer          Berlin    Swimming
# 269899  BRA  2016 Summer  2016  Summer  Rio de Janeiro   Athletics
# 270478  BRA  1952 Summer  1952  Summer        Helsinki    Football
# 270789  BRA  1948 Summer  1948  Summer          London      Boxing
#
#                                          Event Medalha
# 665                Volleyball Men's Volleyball     NaN
# 666                Volleyball Men's Volleyball     NaN
# 668                    Football Men's Football     NaN
# 781              Water Polo Women's Water Polo     NaN
# 1005                 Boxing Men's Middleweight     NaN
# ...                                        ...     ...
# 268652           Basketball Women's Basketball     NaN
# 269745  Swimming Women's 100 metres Backstroke     NaN
# 269899      Athletics Men's 20 kilometres Walk     NaN
# 270478                 Football Men's Football     NaN
# 270789                Boxing Men's Lightweight     NaN
#
# [3848 rows x 15 columns]

# %% [markdown]
# ###FILTRANDO ATLETAS BRASILEIROS QUE PARTICIPARAM NO VERÃO

# %%
# Criando um novo df apenas com dados de atletas brasileiros que participaram nos esportes de Verão 

atletas_brasileiros_verao = atletas_brasileiros_df[atletas_brasileiros_df['Estação'] == 'Summer']
atletas_brasileiros_verao
# Out:
#             ID                        Nome Sexo  Idade  Altura  Peso    Team  \
# 665        386             Alexandre Abeid    M   22.0   194.0  92.0  Brazil
# 666        386             Alexandre Abeid    M   26.0   194.0  92.0  Brazil
# 668        388  Abel Carlos da Silva Braga    M   19.0   190.0  73.0  Brazil
# 781        451         Diana Monteiro Abla    F   21.0   175.0  75.0  Brazil
# 1005       565        Glauclio Serro Abreu    M   26.0   185.0  75.0  Brazil
# ...        ...                         ...  ...    ...     ...   ...     ...
# 268652  134400   Maria Jos "Zz" Bertolotti    F   26.0   190.0   NaN  Brazil
# 269745  134976       Sieglinda Lenk Zigler    F   17.0     NaN   NaN  Brazil
# 269899  135037           Moacir Zimmermann    M   32.0   184.0  70.0  Brazil
# 270478  135289        Zzimo Alves Calazans    M   20.0     NaN   NaN  Brazil
# 270789  135423        Ral Benedito Zumbano    M   22.0     NaN   NaN  Brazil
#
#         NOC        Jogos   Ano Estação            City     Esporte  \
# 665     BRA  1972 Summer  1972  Summer          Munich  Volleyball
# 666     BRA  1976 Summer  1976  Summer        Montreal  Volleyball
# 668     BRA  1972 Summer  1972  Summer          Munich    Football
# 781     BRA  2016 Summer  2016  Summer  Rio de Janeiro  Water Polo
# 1005    BRA  2004 Summer  2004  Summer          Athina      Boxing
# ...     ...          ...   ...     ...             ...         ...
# 268652  BRA  1992 Summer  1992  Summer       Barcelona  Basketball
# 269745  BRA  1936 Summer  1936  Summer          Berlin    Swimming
# 269899  BRA  2016 Summer  2016  Summer  Rio de Janeiro   Athletics
# 270478  BRA  1952 Summer  1952  Summer        Helsinki    Football
# 270789  BRA  1948 Summer  1948  Summer          London      Boxing
#
#                                          Event Medalha
# 665                Volleyball Men's Volleyball     NaN
# 666                Volleyball Men's Volleyball     NaN
# 668                    Football Men's Football     NaN
# 781              Water Polo Women's Water Polo     NaN
# 1005                 Boxing Men's Middleweight     NaN
# ...                                        ...     ...
# 268652           Basketball Women's Basketball     NaN
# 269745  Swimming Women's 100 metres Backstroke     NaN
# 269899      Athletics Men's 20 kilometres Walk     NaN
# 270478                 Football Men's Football     NaN
# 270789                Boxing Men's Lightweight     NaN
#
# [3784 rows x 15 columns]

# %% [markdown]
# ###FILTRANDO APENAS AS MULHERES BRASILEIRAS QUE PARTICIPARAM DAS OLIMPÍADAS DE VERÃO

# %%
# Df de mulheres brasileiras que participaram nos esportes de Verão 
atletas_brasileiras_verao = atletas_brasileiros_df.loc[(atletas_brasileiros_df["Estação"] == "Summer") & (atletas_brasileiros_df["NOC"] == "BRA") & (atletas_brasileiros_df["Sexo"] == "F")]
atletas_brasileiras_verao
# Out:
#             ID                                 Nome Sexo  Idade  Altura  Peso  \
# 781        451                  Diana Monteiro Abla    F   21.0   175.0  75.0
# 1668       925  Adenzia Aparecida Ferreira da Silva    F   25.0   187.0  65.0
# 1669       925  Adenzia Aparecida Ferreira da Silva    F   29.0   187.0  65.0
# 1855      1020         Adriana Aparecida dos Santos    F   21.0   180.0  61.0
# 1856      1020         Adriana Aparecida dos Santos    F   25.0   180.0  61.0
# ...        ...                                  ...  ...    ...     ...   ...
# 267755  133947                   Danielle Zangrando    F   16.0   162.0  57.0
# 267756  133947                   Danielle Zangrando    F   25.0   162.0  57.0
# 268651  134399     Maria Jos "Zez" Batista de Sales    F   31.0   172.0  73.0
# 268652  134400            Maria Jos "Zz" Bertolotti    F   26.0   190.0   NaN
# 269745  134976                Sieglinda Lenk Zigler    F   17.0     NaN   NaN
#
#           Team  NOC        Jogos   Ano Estação            City     Esporte  \
# 781     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro  Water Polo
# 1668    Brazil  BRA  2012 Summer  2012  Summer          London  Volleyball
# 1669    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro  Volleyball
# 1855    Brazil  BRA  1992 Summer  1992  Summer       Barcelona  Basketball
# 1856    Brazil  BRA  1996 Summer  1996  Summer         Atlanta  Basketball
# ...        ...  ...          ...   ...     ...             ...         ...
# 267755  Brazil  BRA  1996 Summer  1996  Summer         Atlanta        Judo
# 267756  Brazil  BRA  2004 Summer  2004  Summer          Athina        Judo
# 268651  Brazil  BRA  2000 Summer  2000  Summer          Sydney    Handball
# 268652  Brazil  BRA  1992 Summer  1992  Summer       Barcelona  Basketball
# 269745  Brazil  BRA  1936 Summer  1936  Summer          Berlin    Swimming
#
#                                          Event Medalha
# 781              Water Polo Women's Water Polo     NaN
# 1668             Volleyball Women's Volleyball    Gold
# 1669             Volleyball Women's Volleyball     NaN
# 1855             Basketball Women's Basketball     NaN
# 1856             Basketball Women's Basketball  Silver
# ...                                        ...     ...
# 267755                Judo Women's Lightweight     NaN
# 267756                Judo Women's Lightweight     NaN
# 268651               Handball Women's Handball     NaN
# 268652           Basketball Women's Basketball     NaN
# 269745  Swimming Women's 100 metres Backstroke     NaN
#
# [1127 rows x 15 columns]

# %%
# filtragem de atletas brasileiras e calculos da média, mínimo e máximo de idade e altura
media_idade_mulheres = atletas_brasileiras_verao['Idade'].mean()
print('Média de idade das mulheres:', media_idade_mulheres)

min_idade_mulheres = atletas_brasileiras_verao['Idade'].min()
print('Idade mínima das mulheres:', min_idade_mulheres)

max_idade_mulheres = atletas_brasileiras_verao['Idade'].max()
print('Idade máxima das mulheres:', max_idade_mulheres)

media_altura_mulheres = atletas_brasileiras_verao['Altura'].mean()
print('Média de altura das mulheres:', media_altura_mulheres)

min_altura_mulheres = atletas_brasileiras_verao['Altura'].min()
print('Altura mínima das mulheres:', min_altura_mulheres)

max_altura_mulheres = atletas_brasileiras_verao['Altura'].max()
print('Altura máxima das mulheres:', max_altura_mulheres)
# Out:
# Média de idade das mulheres: 24.642413487133982
# Idade mínima das mulheres: 13.0
# Idade máxima das mulheres: 54.0
# Média de altura das mulheres: 169.0377714825307
# Altura mínima das mulheres: 133.0
# Altura máxima das mulheres: 200.0

# %% [markdown]
# ###FILTRANDO APENAS OS HOMENS BRASILEIROS QUE PARTICIPARAM DAS OLIMPÍADAS DE VERÃO

# %%
# Df de homens brasileiros que participaram nos esportes de Verão 
atletas_homens_verao = atletas_brasileiros_verao.loc[(df["Estação"] == "Summer") & (atletas_brasileiros_verao["NOC"] == "BRA") & (atletas_brasileiros_verao["Sexo"] == "M")]
atletas_homens_verao
# Out:
#             ID                               Nome Sexo  Idade  Altura  Peso  \
# 665        386                    Alexandre Abeid    M   22.0   194.0  92.0
# 666        386                    Alexandre Abeid    M   26.0   194.0  92.0
# 668        388         Abel Carlos da Silva Braga    M   19.0   190.0  73.0
# 1005       565               Glauclio Serro Abreu    M   26.0   185.0  75.0
# 1017       569  Paulo Francisco Joazeiro de Abreu    M   18.0   176.0  78.0
# ...        ...                                ...  ...    ...     ...   ...
# 268247  134211             Jos Carlos Cracco Neto    M   22.0   170.0  69.0
# 268249  134213            Luiz Eymard Coelho Zech    M   22.0   186.0  76.0
# 269899  135037                  Moacir Zimmermann    M   32.0   184.0  70.0
# 270478  135289               Zzimo Alves Calazans    M   20.0     NaN   NaN
# 270789  135423               Ral Benedito Zumbano    M   22.0     NaN   NaN
#
#           Team  NOC        Jogos   Ano Estação            City     Esporte  \
# 665     Brazil  BRA  1972 Summer  1972  Summer          Munich  Volleyball
# 666     Brazil  BRA  1976 Summer  1976  Summer        Montreal  Volleyball
# 668     Brazil  BRA  1972 Summer  1972  Summer          Munich    Football
# 1005    Brazil  BRA  2004 Summer  2004  Summer          Athina      Boxing
# 1017    Brazil  BRA  1984 Summer  1984  Summer     Los Angeles  Water Polo
# ...        ...  ...          ...   ...     ...             ...         ...
# 268247  Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro    Football
# 268249  Brazil  BRA  1972 Summer  1972  Summer          Munich  Volleyball
# 269899  Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro   Athletics
# 270478  Brazil  BRA  1952 Summer  1952  Summer        Helsinki    Football
# 270789  Brazil  BRA  1948 Summer  1948  Summer          London      Boxing
#
#                                      Event Medalha
# 665            Volleyball Men's Volleyball     NaN
# 666            Volleyball Men's Volleyball     NaN
# 668                Football Men's Football     NaN
# 1005             Boxing Men's Middleweight     NaN
# 1017           Water Polo Men's Water Polo     NaN
# ...                                    ...     ...
# 268247             Football Men's Football    Gold
# 268249         Volleyball Men's Volleyball     NaN
# 269899  Athletics Men's 20 kilometres Walk     NaN
# 270478             Football Men's Football     NaN
# 270789            Boxing Men's Lightweight     NaN
#
# [2657 rows x 15 columns]

# %% [markdown]
# ###DIVIDINDO A PARTICIPAÇÃO DE BRASILEIROS EM CADA ESPORTE, POR GÊNERO

# %%
# Agrupar os dados por esporte e sexo e contar a quantidade de atletas em cada grupo
atletas_por_esporte_sexo = atletas_brasileiros_verao.groupby(['Esporte', 'Sexo'])['Nome'].count().reset_index()

# Renomear a coluna 'Nome' para 'Count'
atletas_por_esporte_sexo = atletas_por_esporte_sexo.rename(columns={'Nome': 'Count'})
print(atletas_por_esporte_sexo)
# Out:
#              Esporte Sexo  Count
# 0            Archery    F      7
# 1            Archery    M     14
# 2   Art Competitions    M      1
# 3          Athletics    F    156
# 4          Athletics    M    363
# ..               ...  ...    ...
# 60        Water Polo    M     83
# 61     Weightlifting    F      4
# 62     Weightlifting    M     21
# 63         Wrestling    F      6
# 64         Wrestling    M      7
#
# [65 rows x 3 columns]

# %% [markdown]
# ###PRIMEIRA MULHER BRASILEIRA A PARTICIPAR DAS OLIMPÍADAS

# %%
# Filtrando a primeira mulher brasileira a participar das Olimpíadas e informações
primeira_mulher = atletas_brasileiras_verao.loc[df['Sexo'] == 'F'].sort_values('Ano').iloc[0]
primeira_mulher
# Out:
# ID                                         68718
# Nome                Maria Emma Hulda Lenk Zigler
# Sexo                                           F
# Idade                                       17.0
# Altura                                     168.0
# Peso                                         NaN
# Team                                      Brazil
# NOC                                          BRA
# Jogos                                1932 Summer
# Ano                                         1932
# Estação                                   Summer
# City                                 Los Angeles
# Esporte                                 Swimming
# Event      Swimming Women's 100 metres Freestyle
# Medalha                                      NaN
# Name: 136660, dtype: object

# %% [markdown]
# ###Ranking de esportes com mais medalhas femininas

# %%
# filtrando mulheres medalhistas:
medalhistas = atletas_brasileiras_verao[(atletas_brasileiras_verao['Medalha'].isna()==False)]

# selecionando variaveis:
medalhistas = medalhistas[['Sexo', 'NOC', 'Ano', 'Esporte', 'Medalha']]

# retirando linhas duplicadas:
medalhistas = medalhistas.drop_duplicates()

# agrupando:
ranking = medalhistas.groupby(['Esporte'])

# contando os valores:
ranking = ranking['Medalha'].count().reset_index()

# ordenando e pegando os 5 primeiros:
ranking = ranking.sort_values(by='Medalha', ascending=False).head(5)

# filtrando os esportes do ranking entre os medalhistas:
medalhas = medalhistas[(medalhistas['Esporte'].isin(ranking['Esporte']))]

# contando quantas medalhas de ouro, prata e bronze cada esporte do ranking tem
medalhas = medalhas[['Esporte', 'Medalha']].groupby(['Esporte']).value_counts().reset_index()

print(medalhas)
# Out:
#             Esporte Medalha  0
# 0        Basketball  Bronze  1
# 1        Basketball  Silver  1
# 2  Beach Volleyball  Silver  4
# 3  Beach Volleyball  Bronze  2
# 4  Beach Volleyball    Gold  1
# 5          Football  Silver  2
# 6              Judo  Bronze  3
# 7              Judo    Gold  2
# 8        Volleyball  Bronze  2
# 9        Volleyball    Gold  2

# %%
# Agrupar o nome das atletas mulheres com a soma de medalhas
medalhas_por_brasileira= atletas_brasileiras_verao.groupby(['Nome'])['Medalha'].count().reset_index(name='Total')

# Filtrar apenas as atletas que tem medalhas e ordenar de maneira decrescente
medalhistas_brasileiras= medalhas_por_brasileira[medalhas_por_brasileira['Total'] > 0]
medalhistas_brasileiras = medalhistas_brasileiras.sort_values(by='Total', ascending=False)
print(medalhistas_brasileiras.head())
# Out:
#                                   Nome  Total
# 224  Hlia "Fofo" Rogrio de Souza Pinto      3
# 162   Fabiana "Fabi" Alvim de Oliveira      2
# 447    Renata Aparacida "Kki" da Costa      2
# 115                 Daniela Alves Lima      2
# 478            Shelda Kelly Bruno Bede      2

# %%
# CORRELAÇÃO da altura e peso das atletas brasileiras dentro de todos os esportes de Verão
altura_peso = atletas_brasileiras_verao[['Altura', 'Peso']]
correlacao = altura_peso.corr()
print(f"A correlação entre altura e peso das mulheres brasileiras é: {correlacao.iloc[0,1]}")
print("Há uma forte correlação positiva entre as variáveis, indicando que quanto maior a altura, maior é o peso das mulheres")
# Out:
# A correlação entre altura e peso das mulheres brasileiras é: 0.8060067105306642
# Há uma forte correlação positiva entre as variáveis, indicando que quanto maior a altura, maior é o peso das mulheres

# %%
sns.set(style="white", color_codes=True)
x=  atletas_brasileiras_verao['Altura']
y= atletas_brasileiras_verao['Peso']
sns.jointplot(x="Altura", y="Peso", data=atletas_brasileiras_verao, kind='reg', height=8)
plt.subplots_adjust(top=0.95)
plt.suptitle('Correlação entre altura e peso das mulheres brasileiras')
plt.show()

# %%
# CORRELAÇÃO da altura e peso das Nadadoras Brasileiras de Verão 

natacao = atletas_brasileiras_verao.loc[atletas_brasileiras_verao['Esporte'] == 'Swimming']
correlacao = natacao['Altura'].corr(natacao['Peso'])

plt.scatter(natacao['Peso'], natacao['Altura'])
plt.xlabel('Peso (kg)')
plt.ylabel('Altura (m)')
plt.title('Correlação entre peso e altura na Natação')
plt.show()

# %%
# CORRELAÇÃO da altura e peso das Atletistas Brasileiras de Verão 

atletismo = atletas_brasileiras_verao.loc[atletas_brasileiras_verao['Esporte'] == 'Athletics']
correlacao = atletismo['Altura'].corr(atletismo['Peso'])

plt.scatter(atletismo['Peso'], atletismo['Altura'])
plt.xlabel('Peso (kg)')
plt.ylabel('Altura (m)')
plt.title('Correlação entre peso e altura no Atletismo')
plt.show()

# %%
# CORRELAÇÃO da altura e peso das atletas de Volei do Brasl no Verão 

volei = atletas_brasileiras_verao.loc[atletas_brasileiras_verao['Esporte'] == 'Volleyball']
correlacao = volei['Altura'].corr(volei['Peso'])

plt.scatter(volei['Peso'], volei['Altura'])
plt.xlabel('Peso (kg)')
plt.ylabel('Altura (m)')
plt.title('Correlação entre peso e altura no Vôlei')
plt.show()

# %%
# CORRELAÇÃO da altura e peso das Ginastas Brasileiras no Verão 

Gymnastics = atletas_brasileiras_verao.loc[atletas_brasileiras_verao['Esporte'] == 'Gymnastics']
correlacao = Gymnastics['Altura'].corr(Gymnastics['Peso'])

plt.scatter(Gymnastics['Peso'], Gymnastics['Altura'])
plt.xlabel('Peso (kg)')
plt.ylabel('Altura (m)')
plt.title('Correlação entre peso e altura na Ginástica')
plt.show()

# %%
# Agrupa os dados por esporte e calcula as correlações entre peso e altura dentro de cada grupo
correlacoes_por_esporte = atletas_brasileiras_verao.groupby('Esporte')[['Peso', 'Altura']].corr().iloc[::2,-1]

# Imprime as correlações
print(correlacoes_por_esporte)
# Out:
# Esporte
# Archery                Peso    0.739150
# Athletics              Peso    0.713523
# Badminton              Peso         NaN
# Basketball             Peso    0.765933
# Beach Volleyball       Peso    0.612163
# Boxing                 Peso    0.940137
# Canoeing               Peso    1.000000
# Cycling                Peso    0.150272
# Diving                 Peso   -0.925605
# Equestrianism          Peso   -0.765652
# Fencing                Peso    0.629620
# Football               Peso    0.796363
# Golf                   Peso    1.000000
# Gymnastics             Peso    0.272351
# Handball               Peso    0.815391
# Judo                   Peso    0.716031
# Modern Pentathlon      Peso    1.000000
# Rhythmic Gymnastics    Peso    0.832670
# Rowing                 Peso    0.604567
# Rugby Sevens           Peso    0.862032
# Sailing                Peso    0.740360
# Shooting               Peso    0.670583
# Swimming               Peso    0.718841
# Synchronized Swimming  Peso    0.639168
# Table Tennis           Peso    0.213498
# Taekwondo              Peso    0.614067
# Tennis                 Peso    0.266252
# Triathlon              Peso   -0.407685
# Volleyball             Peso    0.645085
# Water Polo             Peso    0.881512
# Weightlifting          Peso    0.859577
# Wrestling              Peso    0.830067
# Name: Altura, dtype: float64

# %%
# Criando um novo DataFrame com as colunas de interesse
df_corr = atletas_brasileiras_verao[['Esporte', 'Peso', 'Altura']]

# Agrupando os dados por esporte e calculando a média de peso e altura
df_corr = df_corr.groupby('Esporte').mean().reset_index()

# %%
import seaborn as sns
# Plotando o gráfico de dispersão das correlações de peso e altura com os esportes
sns.pairplot(df_corr, x_vars=['Peso'], y_vars=['Altura'], hue='Esporte', height=5)
